# %% [markdown]
# # Image Processing

# %% [markdown]
# ** Here we will learn how to implement Pillow library to do image processing which will help in Image Augmentation

# %%
from PIL import Image
import numpy as np

# %% [markdown]
# ** Fetching Image

# %%
image_path=r'C:\Users\Shiva\Downloads\Dataset\Lenna_(test_image).png'

# %% [markdown]
# ** To read Image using PIL

# %%
def read_image(image_path):
    try:
        image=Image.open(image_path)
        return image
    except Exception as e:
        print(e)

# %%
image=read_image(image_path)

# %%
image  # image taken from wikipedia
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x1701A766588>

# %% [markdown]
# ** In order to process the image we have to converting image into array

# %%
img_array=np.array(image)

# %%
print(img_array)
# Out:
# [[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  ...
#
#  [[ 84  18  60]
#   [ 84  18  60]
#   [ 92  27  58]
#   ...
#   [173  73  84]
#   [172  68  76]
#   [177  62  79]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]]

# %% [markdown]
# ** to check image size

# %%
def get_image_res(image):
    return (image.size)

# %%
print(get_image_res(image))
# Out:
# (512, 512)

# %% [markdown]
# #### Image resize

# %%
def resize_image(image,h,w):
    resized_image=image.resize((h,w))
    return resized_image

# %%
re=resize_image(image,300,300)

# %%
print(get_image_res(re))
# Out:
# (300, 300)

# %%
re
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x1701A933988>

# %% [markdown]
# #### Image Crop

# %%
def crop(image,left,top,right,bottom):
    cropped=image.crop((left,top,right,bottom))
    return cropped

# %%
cropped=crop(image,100,200,250,350)

# %%
cropped.size
# Out:
# (150, 150)

# %%
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x1701717BDC8>

# %% [markdown]
# #### Center Crop

# %%
def center_image(image):
    width,height=image.size
    left=width/4
    top=height/4
    right=3*width/4
    bottom=3*height/4
    return ((left,top,right,bottom))

# %%
center=center_image(image)
print(center)
# Out:
# (128.0, 128.0, 384.0, 384.0)

# %%
left,top,right,bottom=center
center_cropped=crop(image,left,top,right,bottom)

# %%
center_cropped.size
# Out:
# (256, 256)

# %%
center_cropped
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x170190FD408>

# %% [markdown]
# #### Image Rotating

# %%
def rotate_image(re,angle):
    return re.rotate(angle)

# %%
rot_30=rotate_image(re,30)
rot_30
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x1701A92FC08>

# %%
rot_60=rotate_image(re,60)
rot_60
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x1701A936E08>

# %%
print(img_array.shape)
# Out:
# (512, 512, 3)

# %% [markdown]
# #### Grayscale image

# %%
def convert_to_grayscale(image):
    grayscale=image.convert("L")
    return grayscale

# %%
grayscale=convert_to_grayscale(re)

# %%
grayscale
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x1701A7F5A08>

# %% [markdown]
# #### Binary image

# %%
def get_binary_image(image,threshold):
    grayscale=convert_to_grayscale(re)
    arr=np.array(grayscale)
    for i in range(0,len(arr)):
        for j in range(0,len(arr[i])):
            if arr[i][j]>=threshold:
                arr[i][j]=255
            else:
                arr[i][j]=0
    return arr

# %%
bin_img=get_binary_image(image,100)

# %%
bin_img=Image.fromarray(bin_img)

# %%
bin_img
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x1701B997C48>
