# %% [markdown]
# # Image Processing

# %% [markdown]
# ** Here we will learn how to implement Pillow library to do image processing which will help in Image Augmentation

# %%
from PIL import Image
import numpy as np

# %% [markdown]
# ** Fetching Image

# %%
image_path=r'/content/ashakrishna_2.png'

# %% [markdown]
# ** To read Image using PIL

# %%
def read_image(image_path):
    try:
        image=Image.open(image_path)
        return image
    except Exception as e:
        print(e)

# %%
image=read_image(image_path)

# %%
image  # image taken from wikipedia
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=564x605 at 0x7FEAEA5A10B8>

# %% [markdown]
# ** In order to process the image we have to converting image into array

# %%
img_array=np.array(image)

# %%
print(img_array)
# Out:
# [[[ 22  33  29 255]
#   [ 22  33  29 255]
#   [ 22  33  29 255]
#   ...
#   [ 40  45  41 255]
#   [ 40  45  41 255]
#   [ 40  45  41 255]]
#
#  [[ 22  33  29 255]
#   [ 22  33  29 255]
#   [ 22  33  29 255]
#   ...
#   [ 42  47  43 255]
#   [ 41  46  42 255]
#   [ 41  46  42 255]]
#
#  [[ 21  33  29 255]
#   [ 21  33  29 255]
#   [ 21  33  29 255]
#   ...
#   [ 42  47  43 255]
#   [ 42  47  43 255]
#   [ 42  47  43 255]]
#
#  ...
#
#  [[ 22  33  29 255]
#   [ 22  33  29 255]
#   [ 22  33  29 255]
#   ...
#   [ 14  32  32 255]
#   [ 14  32  32 255]
#   [ 14  32  32 255]]
#
#  [[ 21  33  29 255]
#   [ 21  33  29 255]
#   [ 21  33  29 255]
#   ...
#   [ 13  32  32 255]
#   [ 13  32  32 255]
#   [ 13  32  32 255]]
#
#  [[ 23  31  29 255]
#   [ 23  31  29 255]
#   [ 23  31  29 255]
#   ...
#   [ 16  32  32 255]
#   [ 16  32  32 255]
#   [ 16  32  32 255]]]

# %% [markdown]
# ** to check image size

# %%
def get_image_res(image):
    return (image.size)

# %%
print(get_image_res(image))
# Out:
# (564, 605)

# %% [markdown]
# #### Image resize

# %%
def resize_image(image,h,w):
    resized_image=image.resize((h,w))
    return resized_image

# %%
re=resize_image(image,300,300)

# %%
print(get_image_res(re))
# Out:
# (300, 300)

# %%
re
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7FEAEA522080>

# %% [markdown]
# #### Image Crop

# %%
def crop(image,left,top,right,bottom):
    cropped=image.crop((left,top,right,bottom))
    return cropped

# %%
cropped=crop(image,100,200,250,350)

# %%
cropped.size
# Out:
# (150, 150)

# %%
cropped
# Out:
# <PIL.Image.Image image mode=RGBA size=150x150 at 0x7FEAEA522E80>

# %% [markdown]
# #### Center Crop

# %%
def center_image(image):
    width,height=image.size
    left=width/4
    top=height/4
    right=3*width/4
    bottom=3*height/4
    return ((left,top,right,bottom))

# %%
center=center_image(image)
print(center)
# Out:
# (141.0, 151.25, 423.0, 453.75)

# %%
left,top,right,bottom=center
center_cropped=crop(image,left,top,right,bottom)

# %%
center_cropped.size
# Out:
# (282, 303)

# %%
center_cropped
# Out:
# <PIL.Image.Image image mode=RGBA size=282x303 at 0x7FEAEA52FC88>

# %% [markdown]
# #### Image Rotating

# %%
def rotate_image(re,angle):
    return re.rotate(angle)

# %%
rot_30=rotate_image(re,30)
rot_30
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7FEAEA53B978>

# %%
rot_60=rotate_image(re,60)
rot_60
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7FEAEA53BC18>

# %%
print(img_array.shape)
# Out:
# (605, 564, 4)

# %% [markdown]
# #### Grayscale image

# %%
def convert_to_grayscale(image):
    grayscale=image.convert("L")
    return grayscale

# %%
grayscale=convert_to_grayscale(re)

# %%
grayscale
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7FEAEA52F6A0>

# %% [markdown]
# #### Binary image

# %%
def get_binary_image(image,threshold):
    grayscale=convert_to_grayscale(re)
    arr=np.array(grayscale)
    for i in range(0,len(arr)):
        for j in range(0,len(arr[i])):
            if arr[i][j]>=threshold:
                arr[i][j]=255
            else:
                arr[i][j]=0
    return arr

# %%
bin_img=get_binary_image(image,100)

# %%
bin_img=Image.fromarray(bin_img)

# %%
bin_img
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7FEAEA547080>

# %% [markdown]
# In progress..
