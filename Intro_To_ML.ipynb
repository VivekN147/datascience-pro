# %% [markdown]
# ## Intro To Machine Learning

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r'/content/Automobile price data _Raw_.csv')

# %%
df.head(50)
# Out:
#     symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0           3                 ?  alfa-romero  ...       21          27  13495
# 1           3                 ?  alfa-romero  ...       21          27  16500
# 2           1                 ?  alfa-romero  ...       19          26  16500
# 3           2               164         audi  ...       24          30  13950
# 4           2               164         audi  ...       18          22  17450
# 5           2                 ?         audi  ...       19          25  15250
# 6           1               158         audi  ...       19          25  17710
# 7           1                 ?         audi  ...       19          25  18920
# 8           1               158         audi  ...       17          20  23875
# 9           0                 ?         audi  ...       16          22      ?
# 10          2               192          bmw  ...       23          29  16430
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make  ... city-mpg highway-mpg  price
# 200         -1                95  volvo  ...       23          28  16845
# 201         -1                95  volvo  ...       19          25  19045
# 202         -1                95  volvo  ...       18          23  21485
# 203         -1                95  volvo  ...       26          27  22470
# 204         -1                95  volvo  ...       19          25  22625
#
# [5 rows x 26 columns]

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.axes  #list the row labels and columns
# Out:
# [RangeIndex(start=0, stop=205, step=1),
#  Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#         'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#         'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#         'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#         'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#         'highway-mpg', 'price'],
#        dtype='object')]

# %%
df.columns  #list the column names
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.size    #number of elements
# Out:
# 5330

# %%
df.values    #numpy representation of the data
# Out:
# array([[3, '?', 'alfa-romero', ..., 21, 27, '13495'],
#        [3, '?', 'alfa-romero', ..., 21, 27, '16500'],
#        [1, '?', 'alfa-romero', ..., 19, 26, '16500'],
#        ...,
#        [-1, '95', 'volvo', ..., 18, 23, '21485'],
#        [-1, '95', 'volvo', ..., 26, 27, '22470'],
#        [-1, '95', 'volvo', ..., 19, 25, '22625']], dtype=object)

# %%
df.shape     #return the number of dimensionality
# Out:
# (205, 26)

# %%
df.symboling.max()
# Out:
# 3

# %%
df.describe()
# Out:
#         symboling  wheel-base  ...    city-mpg  highway-mpg
# count  205.000000  205.000000  ...  205.000000   205.000000
# mean     0.834146   98.756585  ...   25.219512    30.751220
# std      1.245307    6.021776  ...    6.542142     6.886443
# min     -2.000000   86.600000  ...   13.000000    16.000000
# 25%      0.000000   94.500000  ...   19.000000    25.000000
# 50%      1.000000   97.000000  ...   24.000000    30.000000
# 75%      2.000000  102.400000  ...   30.000000    34.000000
# max      3.000000  120.900000  ...   49.000000    54.000000
#
# [8 rows x 10 columns]

# %%
df.sample(10)    #show random sample data
# Out:
#      symboling normalized-losses        make  ... city-mpg highway-mpg  price
# 203         -1                95       volvo  ...       26          27  22470
# 94           1               128      nissan  ...       31          37   7299
# 181         -1                 ?      toyota  ...       19          24  15750
# 83           3                 ?  mitsubishi  ...       19          24  14869
# 168          2               134      toyota  ...       24          30   9639
# 138          2                83      subaru  ...       31          36   5118
# 40           0                85       honda  ...       27          33  10295
# 66           0                 ?       mazda  ...       31          39  18344
# 178          3               197      toyota  ...       20          24  16558
# 184          2                94  volkswagen  ...       37          46   7995
#
# [10 rows x 26 columns]

# %% [markdown]
# * head()            #first/last n rows
# * describe()        #generate descriptive statistics
# * max(),mnin()      #return max/min values
# * mean(),median()   #return mean/median
# * std()             #standard deviation
# * sample()          #returns a random sample
# * dropna()          #drop all records with missing values

# %%
df.std()
# Out:
# symboling              1.245307
# wheel-base             6.021776
# length                12.337289
# width                  2.145204
# height                 2.443522
# curb-weight          520.680204
# engine-size           41.642693
# compression-ratio      3.972040
# city-mpg               6.542142
# highway-mpg            6.886443
# dtype: float64

# %%
df.dropna()
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3                 ?  alfa-romero  ...       21          27  13495
# 1            3                 ?  alfa-romero  ...       21          27  16500
# 2            1                 ?  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
df.head(50).mean()
# Out:
# symboling             8.400000e-01
# wheel-base            9.758000e+01
# length                1.702460e+02
# width                 6.545000e+01
# height                5.292000e+01
# curb-weight           2.475720e+03
# engine-size           1.274000e+02
# compression-ratio     8.904200e+00
# horsepower           2.222223e+123
# peak-rpm             1.000100e+198
# city-mpg              2.570000e+01
# highway-mpg           3.116000e+01
# dtype: float64

# %%
df.std()
# Out:
# symboling              1.245307
# wheel-base             6.021776
# length                12.337289
# width                  2.145204
# height                 2.443522
# curb-weight          520.680204
# engine-size           41.642693
# compression-ratio      3.972040
# city-mpg               6.542142
# highway-mpg            6.886443
# dtype: float64

# %%
df.height.count()   #calculate length of any column data
# Out:
# 205

# %%
df['length'].mean()  #mean of length
# Out:
# 174.04926829268305

# %%
df_grp=df.groupby(['make'])

# %%
df_grp.head()
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3                 ?  alfa-romero  ...       21          27  13495
# 1            3                 ?  alfa-romero  ...       21          27  16500
# 2            1                 ?  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 194         -2               103        volvo  ...       23          28  12940
# 195         -1                74        volvo  ...       23          28  13415
# 196         -2               103        volvo  ...       24          28  15985
# 197         -1                74        volvo  ...       24          28  16515
# 198         -2               103        volvo  ...       17          22  18420
#
# [96 rows x 26 columns]

# %%
df_grp.mean()
# Out:
#                symboling  wheel-base  ...   city-mpg  highway-mpg
# make                                  ...
# alfa-romero     2.333333   90.566667  ...  20.333333    26.666667
# audi            1.285714  102.271429  ...  18.857143    24.142857
# bmw             0.375000  103.162500  ...  19.375000    25.375000
# chevrolet       1.000000   92.466667  ...  41.000000    46.333333
# dodge           1.000000   95.011111  ...  28.000000    34.111111
# honda           0.615385   94.330769  ...  30.384615    35.461538
# isuzu           0.750000   94.825000  ...  31.000000    36.000000
# jaguar          0.000000  109.333333  ...  14.333333    18.333333
# mazda           1.117647   97.017647  ...  25.705882    31.941176
# mercedes-benz   0.000000  110.925000  ...  18.500000    21.000000
# mercury         1.000000  102.700000  ...  19.000000    24.000000
# mitsubishi      1.846154   95.353846  ...  24.923077    31.153846
# nissan          1.000000   95.722222  ...  27.000000    32.944444
# ...

# %%
df[df['make']=='volvo']
# Out:
#      symboling normalized-losses   make  ... city-mpg highway-mpg  price
# 194         -2               103  volvo  ...       23          28  12940
# 195         -1                74  volvo  ...       23          28  13415
# 196         -2               103  volvo  ...       24          28  15985
# 197         -1                74  volvo  ...       24          28  16515
# 198         -2               103  volvo  ...       17          22  18420
# 199         -1                74  volvo  ...       17          22  18950
# 200         -1                95  volvo  ...       23          28  16845
# 201         -1                95  volvo  ...       19          25  19045
# 202         -1                95  volvo  ...       18          23  21485
# 203         -1                95  volvo  ...       26          27  22470
# 204         -1                95  volvo  ...       19          25  22625
#
# [11 rows x 26 columns]

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
coef=df.corr()

# %%
coef
# Out:
#                    symboling  wheel-base  ...  city-mpg  highway-mpg
# symboling           1.000000   -0.531954  ... -0.035823     0.034606
# wheel-base         -0.531954    1.000000  ... -0.470414    -0.544082
# length             -0.357612    0.874587  ... -0.670909    -0.704662
# width              -0.232919    0.795144  ... -0.642704    -0.677218
# height             -0.541038    0.589435  ... -0.048640    -0.107358
# curb-weight        -0.227691    0.776386  ... -0.757414    -0.797465
# engine-size        -0.105790    0.569329  ... -0.653658    -0.677470
# compression-ratio  -0.178515    0.249786  ...  0.324701     0.265201
# city-mpg           -0.035823   -0.470414  ...  1.000000     0.971337
# highway-mpg         0.034606   -0.544082  ...  0.971337     1.000000
#
# [10 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
sns.pairplot(df,diag_kind='kde')

# %%
sns.heatmap(coef)

# %% [markdown]
# To Be Continued.
